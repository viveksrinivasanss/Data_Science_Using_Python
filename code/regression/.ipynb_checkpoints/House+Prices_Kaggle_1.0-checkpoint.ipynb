# %% [markdown]
# ## House Price Prediction
#
# This dataset is taken from kaggle competition. So, if you want to try then please sign up in kaggle and download the dataset from the competition entry called **"House Prices: Advanced Regression Techniques"**

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %% [markdown]
# ### Load the dataset

# %%
house_df = pd.read_csv('train.csv')
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
house_df.shape
# Out:
# (1460, 81)

# %%
import seaborn as sns
import matplotlib as mplt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.distplot( house_df.SalePrice )
# Out:
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# #### The **SalesPrice** data seems to be skewed. The variable can be transformed using log transformation.

# %%
corr = house_df.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:].corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=1, square=True)

# %% [markdown]
# #### Overall Quality and GrLivArea seems to be highly correlated with the SalesPrice.

# %%
sns.regplot(x = 'OverallQual', y = 'SalePrice', data = house_df, color = 'green')

# %% [markdown]
# ### Finding Missing Values

# %%
msno.matrix( house_df[house_df.columns[pd.isnull(house_df).any()].tolist()] , p = 10, sort = "descending" )

# %%
house_df_clean = house_df.drop(["Id", "Alley", "PoolQC", "MiscFeature"], axis = 1 )

# %%
numeric_cols = house_df_clean.dtypes[house_df_clean.dtypes != "object"].index

# %%
numeric_cols
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
house_df_clean["SalePrice"] = np.log1p(house_df_clean["SalePrice"])

# %%
sns.distplot( house_df_clean.SalePrice)
# Out:
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Transform the variables which are highly skewed

# %%
from scipy.stats import skew

skewed_cols = house_df_clean[numeric_cols].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_cols = skewed_cols[skewed_cols > 0.75]
skewed_cols = skewed_cols.index

house_df_clean[skewed_cols] = np.log1p(house_df_clean[skewed_cols])

# %%
house_df_clean.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0    4.110874       RL     4.189655  9.042040   Pave      Reg         Lvl
# 1    3.044522       RL     4.394449  9.169623   Pave      Reg         Lvl
# 2    4.110874       RL     4.234107  9.328212   Pave      IR1         Lvl
# 3    4.262680       RL     4.110874  9.164401   Pave      IR1         Lvl
# 4    4.110874       RL     4.442651  9.565284   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope    ...     3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside       Gtl    ...           0.0         0.0      0.0
# 1    AllPub       FR2       Gtl    ...           0.0         0.0      0.0
# 2    AllPub    Inside       Gtl    ...           0.0         0.0      0.0
# 3    AllPub    Corner       Gtl    ...           0.0         0.0      0.0
# 4    AllPub       FR2       Gtl    ...           0.0         0.0      0.0
#
#   Fence MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Create Dummy Variables for Categorical Variables

# %%
category_cols = house_df_clean.dtypes[house_df_clean.dtypes == "object"].index

# %%
category_cols
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
house_all_df = pd.get_dummies( house_df_clean )

# %%
house_all_df.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=280)

# %%
house_all_df = house_all_df.fillna( house_all_df.mean() )

# %%
len( house_all_df.columns )
# Out:
# 280

# %% [markdown]
# ### Spit the dataset into train and test

# %%
Y = house_all_df['SalePrice']
X = house_all_df.drop( 'SalePrice', axis = 1 )

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.3, random_state = 42 )

# %% [markdown]
# ## Build a linear regression model

# %%
from sklearn.linear_model import LinearRegression


lreg = LinearRegression()
lreg.fit( X_train, Y_train )
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Validate the model and measure accuracy

# %%
y_pred = lreg.predict( X_test )

# %% [markdown]
# ### R-square and RMSE

# %%
from sklearn import metrics

metrics.r2_score( Y_test, y_pred )
# Out:
# 0.90547838187468677

# %%
np.sqrt( metrics.mean_squared_error( Y_test, y_pred ) )
# Out:
# 0.12662945896388264

# %% [markdown]
# ### Draw the coefficient values

# %%
def draw_coefficient( model, columns ):
    
    all_coefs = pd.Series( model.coef_, index = columns )

    coef_values_df = pd.concat([all_coefs.sort_values().head(10),
                                all_coefs.sort_values().tail(10)])

    mplt.rcParams['figure.figsize'] = (6.0, 8.0)
    coef_values_df.plot(kind = "barh")
    plt.title("Coefficients Values" )

# %%
draw_coefficient( lreg, X_train.columns )

# %% [markdown]
# ## KFold Cross validation

# %%
from sklearn import cross_validation

# %%
lreg = LinearRegression()

lreg_cv_scores = cross_validation.cross_val_score( lreg, X_train, Y_train, scoring = "mean_squared_error", cv = 5 )

# %%
np.mean( list( map( lambda x: np.sqrt( -x ), lreg_cv_scores ) ) )
# Out:
# 0.14623638537079359

# %% [markdown]
# ## Build a Ridge Regression Model

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV

# %%
r_model = Ridge( alpha = 10 )
r_model.fit( X_train, Y_train )
Y_pred_r = r_model.predict( X_test )
metrics.r2_score( Y_test, Y_pred_r )
# Out:
# 0.90678419681716071

# %%
np.sqrt( metrics.mean_squared_error( Y_test, Y_pred_r ) )
# Out:
# 0.12575172477335758

# %%
draw_coefficient( r_model, X_train.columns )

# %% [markdown]
# ## Grid Search For Finding Best Alpha Parameter

# %%
from sklearn.grid_search import GridSearchCV

# %%
parameters = {'alpha':[0.01, 0.1, 1, 5, 10, 15, 20, 30]}
grid = GridSearchCV(r_model,parameters, scoring = "mean_squared_error" , cv=5)
grid.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'alpha': [0.01, 0.1, 1, 5, 10, 15, 20, 30]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='mean_squared_error',
#        verbose=0)

# %%
grid.grid_scores_
# Out:
# [mean: -0.02217, std: 0.01044, params: {'alpha': 0.01},
#  mean: -0.02120, std: 0.01068, params: {'alpha': 0.1},
#  mean: -0.02072, std: 0.00996, params: {'alpha': 1},
#  mean: -0.02051, std: 0.00911, params: {'alpha': 5},
#  mean: -0.02030, std: 0.00881, params: {'alpha': 10},
#  mean: -0.02024, std: 0.00863, params: {'alpha': 15},
#  mean: -0.02024, std: 0.00851, params: {'alpha': 20},
#  mean: -0.02033, std: 0.00834, params: {'alpha': 30}]

# %%
grid.best_score_
# Out:
# -0.020236550637086469

# %%
[scores[0]['alpha'] for scores in grid.grid_scores_]
# Out:
# [0.01, 0.1, 1, 5, 10, 15, 20, 30]

# %%
ridge_rmse = pd.Series( [np.sqrt( -scores[1] ) for scores in grid.grid_scores_], 
                index =  [scores[0]['alpha'] for scores in grid.grid_scores_] )

# %%
ridge_rmse
# Out:
# 0.01     0.148893
# 0.10     0.145599
# 1.00     0.143959
# 5.00     0.143197
# 10.00    0.142467
# 15.00    0.142255
# 20.00    0.142271
# 30.00    0.142574
# dtype: float64

# %%
ridge_rmse.min()
# Out:
# 0.14225523061415515

# %% [markdown]
# ### RMSE Vs. Alpha Parameters

# %%
ridge_rmse.plot(title = "Ridge RMSE Vs. alpha")
plt.xlabel("Alpha Values")
plt.ylabel("RMSE")

# %% [markdown]
# ## Build a Lasso Model

# %%
from sklearn.linear_model import Lasso

# %%
l_model = Lasso( alpha = 0.001 )
l_model.fit( X_train, Y_train )
Y_pred_l = l_model.predict( X_test )
metrics.r2_score( Y_test, Y_pred_l )
# Out:
# 0.90937435984071036

# %%
np.expm1( Y_pred_l[0:10] )
# Out:
# array([ 151218.05578952,  332954.71048789,  105515.68929325,
#         161091.57112554,  327683.204611  ,   78484.16106423,
#         257466.49519699,  142398.70272683,   76307.48817376,
#         143468.37089427])

# %%
np.expm1( Y_test[0:10] )
# Out:
# 892     154500.0
# 1105    325000.0
# 413     115000.0
# 522     159000.0
# 1036    315500.0
# 614      75500.0
# 218     311500.0
# 1160    146000.0
# 649      84500.0
# 887     135500.0
# Name: SalePrice, dtype: float64

# %%
draw_coefficient( l_model, X_train.columns )

# %% [markdown]
# ### Check Variable Shrinkage

# %%
sum( l_model.coef_ == 0.00 )
# Out:
# 201

# %%
l_model = Lasso()
parameters = {'alpha':[0.00001, 0.00005, 0.0001, 0.001, 0.005]}
l_grid = GridSearchCV(l_model,parameters, scoring = "mean_squared_error" , cv=5)
l_grid.fit(X_train, Y_train)

l_grid.grid_scores_
# Out:
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# /Users/manaranjan/anaconda/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# ...

# %%
l_grid.best_score_
# Out:
# -0.019472299031839543

# %%
l_estimate = l_grid.best_estimator_

# %%
selected_features = X_train.columns[ l_estimate.coef_ > 0 ]

# %%
[scores[0]['alpha'] for scores in l_grid.grid_scores_]

lasso_rmse = pd.Series( [np.sqrt( -scores[1] ) for scores in l_grid.grid_scores_], 
                index =  [scores[0]['alpha'] for scores in l_grid.grid_scores_] ) 

lasso_rmse

lasso_rmse.plot(title = "Lasso RMSE Vs. alpha")
plt.xlabel("Alpha Values")
plt.ylabel("RMSE")

# %%
lasso_rmse.min()
# Out:
# 0.13954317981126682

# %% [markdown]
# ## Build the final Model and Predict the Test Dataset

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# ...

# %% [markdown]
# ### Data Cleaning & Transformations

# %%
test_df_clean = test_df.drop(["Id", "Alley", "PoolQC", "MiscFeature"], axis = 1 )

# %%
len( test_df_clean.columns )
# Out:
# 76

# %%
#test_df_clean = test_df_clean.drop( 'SalePrice', axis = 1 )

# %%
test_df_clean[skewed_cols] = np.log1p(test_df_clean[skewed_cols])

test_all_df = pd.get_dummies( test_df_clean )

# %%
len( test_all_df.columns )
# Out:
# 263

# %%
len( X.columns )
# Out:
# 279

# %%
remaining_cols = X.columns.difference( test_all_df.columns )

# %%
for col_name in remaining_cols:
    test_all_df[col_name] = 0.00

# %%
test_all_df.shape
# Out:
# (1459, 279)

# %%
X.shape
# Out:
# (1460, 279)

# %%
test_all_df = test_all_df.fillna( X.mean() )

# %%
final_lasso = Lasso( alpha = 0.001 )

# %%
final_lasso.fit( X, Y )
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
final_y = final_lasso.predict( test_all_df )

# %%
final_y
# Out:
# array([ 11.7085197 ,  11.85709794,  12.0037924 , ...,  12.10623016,
#         11.6153296 ,  12.30621046])

# %%
final_y_exp = np.expm1( final_y )

# %%
sum( final_y_exp > 100000 )
# Out:
# 1338

# %%
np.expm1( Y )[0:10]
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# 5    143000.0
# 6    307000.0
# 7    200000.0
# 8    129900.0
# 9    118000.0
# Name: SalePrice, dtype: float64

# %%
final_submit_df = pd.DataFrame( { 'Id': test_df.Id, 'SalePrice': final_y_exp } )

# %%
final_submit_df[0:10]
# Out:
#      Id      SalePrice
# 0  1461  121602.337848
# 1  1462  141081.194293
# 2  1463  163372.194103
# 3  1464  163917.510716
# 4  1465  174949.466713
# 5  1466  155907.197892
# 6  1467  162625.732292
# 7  1468  138763.422081
# 8  1469  158003.122809
# 9  1470  114234.140226

# %%
final_submit_df.to_csv( "house_price_21_10_1.csv", index = False )

# %% [markdown]
# #### Submit the results to Kaggle
